# %% [markdown]
# # Generation of the simulation
# ### save one example of time series and all measures

# %%
import time as tm
import colorsys
import pickle # package use to save data

exec(open("solver.py").read(), globals())
exec(open("param.py").read(), globals())

# %%
def exemples(name, Number_of_simulation = 100, mean = True, **kwargs):
    name = name+"_freq="+str(kwargs["Fire_param"]["param_freq"]["p"])+".png"
    O = Ode(**kwargs)
    Y = O.solve_by_part()
    O.plot_time_series(save = True, name = name, generation = True, show = False)
    return Y

# %%
def param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name):
   # Color = ["blue", "g", "red", "orange", "pink", "black", "magenta", "grey"]
    Param_coupled = {"alpha":alpha,
                     "beta":beta}
    Param_freq = {"p":-1} # going to change
    Param_strength = {"scale":strength}
    Fire_param = {"model": "coupled",
                    "frequence": "bernoulli",
                    "param_freq" : Param_freq,
                    "amplitude": "exponential",
                    "Param_strength" : Param_strength,
                    "Param_coupled" : Param_coupled,
                    "type" : "proportionnal",
                    "coef_W_N" : 5}

    # Initialization of arrays
    Collapse = np.zeros((numbreDePoint, len(Freq)))
    Variability = np.zeros_like(Collapse)

    
#    Variability_always = np.zeros_like(Collapse)
 #   Variability_until = np.zeros_like(Collapse)
  #  Variability_only = np.zeros_like(Collapse)
   # Variability_10 = np.zeros_like(Collapse)
    #Collapse_10_b = np.zeros_like(Collapse)
    #Collapse_10_m = np.zeros_like(Collapse)
    #Variability_half = np.zeros_like(Collapse)
    #Speed_collapse = np.zeros_like(Collapse)
    #Viability = np.zeros_like(Collapse)
    #Ratio = np.zeros_like(Collapse)
    #Point = np.zeros_like(Collapse)
    #Time_rotation_N = np.zeros_like(Collapse)
    #Time_rotation_W = np.zeros_like(Collapse)
    
    #Exemples = np.zeros(len(Freq))
    
    for i, freq in enumerate(Freq):
        Param_freq = {"p":freq}
        Fire_param["param_freq"] = Param_freq
        exemples(name = name, Number_of_simulation = Number_of_simulation, mean = False, finalTime = finalTime, Fire_param = Fire_param, dt = dt, Param_phy=Param_phy, Init=Init)
        for j in range(numbreDePoint):
            S = Solver(numberOfSimulation=Number_of_simulation, model = "allee_effect_adi", Init=Init, Param_phy= Param_phy, finalTime = finalTime, dt=dt, Fire_param = Fire_param)
            S.run()
            Collapse[j,i] = S.collapse()
            Variability[j,i] = S.variability()

           # print("\nTime solve init", t05-t0)
            #print("Time solver ", t1-t05)
            #print("Time collapse ", t2-t1)
            #print("Time variability ", t3-t2)
            
    Measures = {"Collapse": Collapse,
                "Variability": Variability}
    
    # save data
    pickle_out = open(name+".txt","wb")
    pickle.dump(Measures, pickle_out)
    pickle_out.close()
    
    return

# %%
nomberFigure = len(N0)*len(W0)*len(FinalTime)*len(A)*len(M)*len(Alpha)*len(Beta)*len(Strength)
fig_by_loop = len(Freq) + 1

c=0
for n0 in N0:
    for w0 in W0:
        Init = [n0, w0]
        for finalTime in FinalTime:
            for a in A:
                for m in M:
                    Param_phy = [a, m]
                    #Init = [1., Param_phy[1]]
                    for strength in Strength:
                        for alpha in Alpha:
                            for beta in Beta:
                                name = DOSSIER+"n0="+str(n0)+"_w0="+str(w0)+"_final_time="+str(finalTime)+"_a="+str(a)+"_m="+str(m)+"_strength="+str(strength)+"_alpha="+str(alpha)+"_beta="+str(beta)
                                param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name)           
                                c+=1
                                print(tm.ctime(), ", Figure ", c*fig_by_loop, "(total ", fig_by_loop*nomberFigure, ")") # afficher l'heure
# Out:
# Mon Apr 15 15:51:45 2019 , Figure  16 (total  8064 )
# Mon Apr 15 15:53:54 2019 , Figure  32 (total  8064 )
# Mon Apr 15 15:56:03 2019 , Figure  48 (total  8064 )
# Mon Apr 15 15:58:13 2019 , Figure  64 (total  8064 )
# Mon Apr 15 16:00:23 2019 , Figure  80 (total  8064 )
# Mon Apr 15 16:02:35 2019 , Figure  96 (total  8064 )
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: RuntimeWarning: divide by zero encountered in log
# C:\Users\jerome\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2320: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\jerome\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\jerome\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\jerome\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:72: RuntimeWarning: Mean of empty slice
# Mon Apr 15 16:04:46 2019 , Figure  112 (total  8064 )
# Mon Apr 15 16:06:57 2019 , Figure  128 (total  8064 )
# Mon Apr 15 16:09:09 2019 , Figure  144 (total  8064 )
# Mon Apr 15 16:11:20 2019 , Figure  160 (total  8064 )
# Mon Apr 15 16:13:31 2019 , Figure  176 (total  8064 )
# Mon Apr 15 16:15:42 2019 , Figure  192 (total  8064 )
# Mon Apr 15 16:17:53 2019 , Figure  208 (total  8064 )
# Mon Apr 15 16:20:04 2019 , Figure  224 (total  8064 )
# Mon Apr 15 16:22:15 2019 , Figure  240 (total  8064 )
# Mon Apr 15 16:24:26 2019 , Figure  256 (total  8064 )
# Mon Apr 15 16:26:37 2019 , Figure  272 (total  8064 )
# Mon Apr 15 16:28:48 2019 , Figure  288 (total  8064 )
# Mon Apr 15 16:31:00 2019 , Figure  304 (total  8064 )
# Mon Apr 15 16:33:11 2019 , Figure  320 (total  8064 )
# Mon Apr 15 16:35:23 2019 , Figure  336 (total  8064 )
# Mon Apr 15 16:37:34 2019 , Figure  352 (total  8064 )
# Mon Apr 15 16:39:46 2019 , Figure  368 (total  8064 )
# Mon Apr 15 16:41:54 2019 , Figure  384 (total  8064 )
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:73: RuntimeWarning: Mean of empty slice
# Mon Apr 15 16:44:03 2019 , Figure  400 (total  8064 )
# Mon Apr 15 16:46:15 2019 , Figure  416 (total  8064 )
# Mon Apr 15 16:48:26 2019 , Figure  432 (total  8064 )
# Mon Apr 15 16:50:37 2019 , Figure  448 (total  8064 )
# Mon Apr 15 16:52:50 2019 , Figure  464 (total  8064 )
# Mon Apr 15 16:55:02 2019 , Figure  480 (total  8064 )
# Mon Apr 15 16:57:12 2019 , Figure  496 (total  8064 )
# Mon Apr 15 16:59:22 2019 , Figure  512 (total  8064 )
# Mon Apr 15 17:01:34 2019 , Figure  528 (total  8064 )
# Mon Apr 15 17:03:46 2019 , Figure  544 (total  8064 )
# Mon Apr 15 17:05:58 2019 , Figure  560 (total  8064 )
# Mon Apr 15 17:08:12 2019 , Figure  576 (total  8064 )
# Mon Apr 15 17:10:25 2019 , Figure  592 (total  8064 )
# Mon Apr 15 17:12:37 2019 , Figure  608 (total  8064 )
# Mon Apr 15 17:14:46 2019 , Figure  624 (total  8064 )
# Mon Apr 15 17:16:58 2019 , Figure  640 (total  8064 )
# Mon Apr 15 17:19:11 2019 , Figure  656 (total  8064 )
# Mon Apr 15 17:21:23 2019 , Figure  672 (total  8064 )
# Mon Apr 15 17:23:35 2019 , Figure  688 (total  8064 )
# Mon Apr 15 17:25:46 2019 , Figure  704 (total  8064 )
# Mon Apr 15 17:27:59 2019 , Figure  720 (total  8064 )
# Mon Apr 15 17:30:11 2019 , Figure  736 (total  8064 )
# Mon Apr 15 17:32:20 2019 , Figure  752 (total  8064 )
# Mon Apr 15 17:34:30 2019 , Figure  768 (total  8064 )
# Mon Apr 15 17:36:36 2019 , Figure  784 (total  8064 )
# Mon Apr 15 17:38:43 2019 , Figure  800 (total  8064 )
# Mon Apr 15 17:40:56 2019 , Figure  816 (total  8064 )
# C:\Users\jerome\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\jerome\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:469: RuntimeWarning: invalid value encountered in less
# Mon Apr 15 17:43:10 2019 , Figure  832 (total  8064 )
# Mon Apr 15 17:45:25 2019 , Figure  848 (total  8064 )
# Mon Apr 15 17:47:39 2019 , Figure  864 (total  8064 )
# Mon Apr 15 17:49:54 2019 , Figure  880 (total  8064 )
# Mon Apr 15 17:52:07 2019 , Figure  896 (total  8064 )
# Mon Apr 15 17:54:16 2019 , Figure  912 (total  8064 )
# Mon Apr 15 17:56:22 2019 , Figure  928 (total  8064 )
# Mon Apr 15 17:58:27 2019 , Figure  944 (total  8064 )
# Mon Apr 15 18:00:33 2019 , Figure  960 (total  8064 )
# Mon Apr 15 18:02:36 2019 , Figure  976 (total  8064 )
# Mon Apr 15 18:04:39 2019 , Figure  992 (total  8064 )
# Mon Apr 15 18:06:43 2019 , Figure  1008 (total  8064 )
# Mon Apr 15 18:08:46 2019 , Figure  1024 (total  8064 )
# Mon Apr 15 18:10:49 2019 , Figure  1040 (total  8064 )
# Mon Apr 15 18:12:52 2019 , Figure  1056 (total  8064 )
# Mon Apr 15 18:14:55 2019 , Figure  1072 (total  8064 )
# Mon Apr 15 18:16:59 2019 , Figure  1088 (total  8064 )
# Mon Apr 15 18:19:02 2019 , Figure  1104 (total  8064 )
# Mon Apr 15 18:21:05 2019 , Figure  1120 (total  8064 )
# Mon Apr 15 18:23:08 2019 , Figure  1136 (total  8064 )
# Mon Apr 15 18:25:11 2019 , Figure  1152 (total  8064 )
# Mon Apr 15 18:27:14 2019 , Figure  1168 (total  8064 )
# Mon Apr 15 18:29:18 2019 , Figure  1184 (total  8064 )
# Mon Apr 15 18:31:21 2019 , Figure  1200 (total  8064 )
# Mon Apr 15 18:33:24 2019 , Figure  1216 (total  8064 )
# Mon Apr 15 18:35:27 2019 , Figure  1232 (total  8064 )
# Mon Apr 15 18:37:31 2019 , Figure  1248 (total  8064 )
# Mon Apr 15 18:39:33 2019 , Figure  1264 (total  8064 )
# Mon Apr 15 18:41:36 2019 , Figure  1280 (total  8064 )
# Mon Apr 15 18:43:39 2019 , Figure  1296 (total  8064 )
# Mon Apr 15 18:45:43 2019 , Figure  1312 (total  8064 )
# Mon Apr 15 18:47:46 2019 , Figure  1328 (total  8064 )
# Mon Apr 15 18:49:49 2019 , Figure  1344 (total  8064 )
# Mon Apr 15 18:51:52 2019 , Figure  1360 (total  8064 )
# Mon Apr 15 18:53:55 2019 , Figure  1376 (total  8064 )
# Mon Apr 15 18:55:58 2019 , Figure  1392 (total  8064 )
# Mon Apr 15 18:58:01 2019 , Figure  1408 (total  8064 )
# Mon Apr 15 19:00:03 2019 , Figure  1424 (total  8064 )
# Mon Apr 15 19:02:08 2019 , Figure  1440 (total  8064 )
# Mon Apr 15 19:04:14 2019 , Figure  1456 (total  8064 )
# Mon Apr 15 19:06:20 2019 , Figure  1472 (total  8064 )
# Mon Apr 15 19:08:26 2019 , Figure  1488 (total  8064 )
# Mon Apr 15 19:10:31 2019 , Figure  1504 (total  8064 )
# Mon Apr 15 19:12:36 2019 , Figure  1520 (total  8064 )
# Mon Apr 15 19:14:42 2019 , Figure  1536 (total  8064 )
# Mon Apr 15 19:16:47 2019 , Figure  1552 (total  8064 )
# Mon Apr 15 19:18:52 2019 , Figure  1568 (total  8064 )
# Mon Apr 15 19:20:56 2019 , Figure  1584 (total  8064 )
# Mon Apr 15 19:23:02 2019 , Figure  1600 (total  8064 )
# Mon Apr 15 19:25:07 2019 , Figure  1616 (total  8064 )
# Mon Apr 15 19:27:12 2019 , Figure  1632 (total  8064 )
# Mon Apr 15 19:29:17 2019 , Figure  1648 (total  8064 )
# Mon Apr 15 19:31:21 2019 , Figure  1664 (total  8064 )
# Mon Apr 15 19:33:25 2019 , Figure  1680 (total  8064 )
# Mon Apr 15 19:35:29 2019 , Figure  1696 (total  8064 )
# Mon Apr 15 19:37:33 2019 , Figure  1712 (total  8064 )
# Mon Apr 15 19:39:37 2019 , Figure  1728 (total  8064 )
# Mon Apr 15 19:41:42 2019 , Figure  1744 (total  8064 )
# Mon Apr 15 19:43:47 2019 , Figure  1760 (total  8064 )
# Mon Apr 15 19:45:52 2019 , Figure  1776 (total  8064 )
# Mon Apr 15 19:47:56 2019 , Figure  1792 (total  8064 )
# Mon Apr 15 19:50:00 2019 , Figure  1808 (total  8064 )
# Mon Apr 15 19:52:04 2019 , Figure  1824 (total  8064 )
# Mon Apr 15 19:54:09 2019 , Figure  1840 (total  8064 )
# Mon Apr 15 19:56:13 2019 , Figure  1856 (total  8064 )
# Mon Apr 15 19:58:17 2019 , Figure  1872 (total  8064 )
# Mon Apr 15 20:00:22 2019 , Figure  1888 (total  8064 )
# Mon Apr 15 20:02:27 2019 , Figure  1904 (total  8064 )
# Mon Apr 15 20:04:31 2019 , Figure  1920 (total  8064 )
# Mon Apr 15 20:06:35 2019 , Figure  1936 (total  8064 )
# Mon Apr 15 20:08:39 2019 , Figure  1952 (total  8064 )
# Mon Apr 15 20:10:44 2019 , Figure  1968 (total  8064 )
# Mon Apr 15 20:12:48 2019 , Figure  1984 (total  8064 )
# Mon Apr 15 20:14:52 2019 , Figure  2000 (total  8064 )
# Mon Apr 15 20:16:56 2019 , Figure  2016 (total  8064 )
# Mon Apr 15 20:19:02 2019 , Figure  2032 (total  8064 )
# Mon Apr 15 20:21:07 2019 , Figure  2048 (total  8064 )
# Mon Apr 15 20:23:12 2019 , Figure  2064 (total  8064 )
# Mon Apr 15 20:25:18 2019 , Figure  2080 (total  8064 )
# Mon Apr 15 20:27:24 2019 , Figure  2096 (total  8064 )
# Mon Apr 15 20:29:29 2019 , Figure  2112 (total  8064 )
# Mon Apr 15 20:31:35 2019 , Figure  2128 (total  8064 )
# Mon Apr 15 20:33:41 2019 , Figure  2144 (total  8064 )
# Mon Apr 15 20:35:47 2019 , Figure  2160 (total  8064 )
# Mon Apr 15 20:37:52 2019 , Figure  2176 (total  8064 )
# Mon Apr 15 20:39:58 2019 , Figure  2192 (total  8064 )
# Mon Apr 15 20:42:04 2019 , Figure  2208 (total  8064 )
# Mon Apr 15 20:44:09 2019 , Figure  2224 (total  8064 )
# Mon Apr 15 20:46:15 2019 , Figure  2240 (total  8064 )
# Mon Apr 15 20:48:21 2019 , Figure  2256 (total  8064 )
# Mon Apr 15 20:50:27 2019 , Figure  2272 (total  8064 )
# Mon Apr 15 20:52:32 2019 , Figure  2288 (total  8064 )
# Mon Apr 15 20:54:38 2019 , Figure  2304 (total  8064 )
# Mon Apr 15 20:56:43 2019 , Figure  2320 (total  8064 )
# Mon Apr 15 20:58:49 2019 , Figure  2336 (total  8064 )
# Mon Apr 15 21:00:55 2019 , Figure  2352 (total  8064 )
# Mon Apr 15 21:03:01 2019 , Figure  2368 (total  8064 )
# Mon Apr 15 21:05:07 2019 , Figure  2384 (total  8064 )
# Mon Apr 15 21:07:12 2019 , Figure  2400 (total  8064 )
# Mon Apr 15 21:09:18 2019 , Figure  2416 (total  8064 )
# Mon Apr 15 21:11:24 2019 , Figure  2432 (total  8064 )
# Mon Apr 15 21:13:30 2019 , Figure  2448 (total  8064 )
# Mon Apr 15 21:15:35 2019 , Figure  2464 (total  8064 )
# Mon Apr 15 21:17:41 2019 , Figure  2480 (total  8064 )
# Mon Apr 15 21:19:47 2019 , Figure  2496 (total  8064 )
# Mon Apr 15 21:21:54 2019 , Figure  2512 (total  8064 )
# Mon Apr 15 21:24:00 2019 , Figure  2528 (total  8064 )
# Mon Apr 15 21:26:06 2019 , Figure  2544 (total  8064 )
# Mon Apr 15 21:28:11 2019 , Figure  2560 (total  8064 )
# Mon Apr 15 21:30:18 2019 , Figure  2576 (total  8064 )
# Mon Apr 15 21:32:24 2019 , Figure  2592 (total  8064 )
# Mon Apr 15 21:34:30 2019 , Figure  2608 (total  8064 )
# Mon Apr 15 21:36:34 2019 , Figure  2624 (total  8064 )
# Mon Apr 15 21:38:41 2019 , Figure  2640 (total  8064 )
# Mon Apr 15 21:40:46 2019 , Figure  2656 (total  8064 )
# Mon Apr 15 21:42:52 2019 , Figure  2672 (total  8064 )
# Mon Apr 15 21:44:58 2019 , Figure  2688 (total  8064 )
# Mon Apr 15 21:47:03 2019 , Figure  2704 (total  8064 )
# Mon Apr 15 21:49:09 2019 , Figure  2720 (total  8064 )
# Mon Apr 15 21:51:15 2019 , Figure  2736 (total  8064 )
# Mon Apr 15 21:53:21 2019 , Figure  2752 (total  8064 )
# Mon Apr 15 21:55:27 2019 , Figure  2768 (total  8064 )
# Mon Apr 15 21:57:33 2019 , Figure  2784 (total  8064 )
# Mon Apr 15 21:59:39 2019 , Figure  2800 (total  8064 )
# Mon Apr 15 22:01:45 2019 , Figure  2816 (total  8064 )
# Mon Apr 15 22:03:52 2019 , Figure  2832 (total  8064 )
# Mon Apr 15 22:05:58 2019 , Figure  2848 (total  8064 )
# Mon Apr 15 22:08:04 2019 , Figure  2864 (total  8064 )
# Mon Apr 15 22:10:10 2019 , Figure  2880 (total  8064 )
# Mon Apr 15 22:12:17 2019 , Figure  2896 (total  8064 )
# Mon Apr 15 22:14:24 2019 , Figure  2912 (total  8064 )
# Mon Apr 15 22:16:31 2019 , Figure  2928 (total  8064 )
# Mon Apr 15 22:18:37 2019 , Figure  2944 (total  8064 )
# Mon Apr 15 22:20:45 2019 , Figure  2960 (total  8064 )
# Mon Apr 15 22:22:51 2019 , Figure  2976 (total  8064 )
# Mon Apr 15 22:24:58 2019 , Figure  2992 (total  8064 )
# Mon Apr 15 22:27:04 2019 , Figure  3008 (total  8064 )
# Mon Apr 15 22:29:11 2019 , Figure  3024 (total  8064 )
# Mon Apr 15 22:31:18 2019 , Figure  3040 (total  8064 )
# Mon Apr 15 22:33:24 2019 , Figure  3056 (total  8064 )
# Mon Apr 15 22:35:31 2019 , Figure  3072 (total  8064 )
# Mon Apr 15 22:37:38 2019 , Figure  3088 (total  8064 )
# Mon Apr 15 22:39:45 2019 , Figure  3104 (total  8064 )
# Mon Apr 15 22:41:52 2019 , Figure  3120 (total  8064 )
# Mon Apr 15 22:43:59 2019 , Figure  3136 (total  8064 )
# Mon Apr 15 22:46:06 2019 , Figure  3152 (total  8064 )
# Mon Apr 15 22:48:13 2019 , Figure  3168 (total  8064 )
# Mon Apr 15 22:50:19 2019 , Figure  3184 (total  8064 )
# Mon Apr 15 22:52:26 2019 , Figure  3200 (total  8064 )
# Mon Apr 15 22:54:33 2019 , Figure  3216 (total  8064 )
# Mon Apr 15 22:56:39 2019 , Figure  3232 (total  8064 )
# Mon Apr 15 22:58:46 2019 , Figure  3248 (total  8064 )
# Mon Apr 15 23:00:53 2019 , Figure  3264 (total  8064 )
# Mon Apr 15 23:02:59 2019 , Figure  3280 (total  8064 )
# Mon Apr 15 23:05:06 2019 , Figure  3296 (total  8064 )
# Mon Apr 15 23:07:13 2019 , Figure  3312 (total  8064 )
# Mon Apr 15 23:09:19 2019 , Figure  3328 (total  8064 )
# Mon Apr 15 23:11:26 2019 , Figure  3344 (total  8064 )
# Mon Apr 15 23:13:33 2019 , Figure  3360 (total  8064 )
# Mon Apr 15 23:15:39 2019 , Figure  3376 (total  8064 )
# Mon Apr 15 23:17:45 2019 , Figure  3392 (total  8064 )
# Mon Apr 15 23:19:52 2019 , Figure  3408 (total  8064 )
# Mon Apr 15 23:21:58 2019 , Figure  3424 (total  8064 )
# Mon Apr 15 23:24:04 2019 , Figure  3440 (total  8064 )
# Mon Apr 15 23:26:10 2019 , Figure  3456 (total  8064 )
# Mon Apr 15 23:28:16 2019 , Figure  3472 (total  8064 )
# Mon Apr 15 23:30:23 2019 , Figure  3488 (total  8064 )
# Mon Apr 15 23:32:30 2019 , Figure  3504 (total  8064 )
# Mon Apr 15 23:34:35 2019 , Figure  3520 (total  8064 )
# Mon Apr 15 23:36:41 2019 , Figure  3536 (total  8064 )
# Mon Apr 15 23:38:46 2019 , Figure  3552 (total  8064 )
# Mon Apr 15 23:40:52 2019 , Figure  3568 (total  8064 )
# Mon Apr 15 23:42:57 2019 , Figure  3584 (total  8064 )
# Mon Apr 15 23:45:02 2019 , Figure  3600 (total  8064 )
# Mon Apr 15 23:47:08 2019 , Figure  3616 (total  8064 )
# Mon Apr 15 23:49:13 2019 , Figure  3632 (total  8064 )
# Mon Apr 15 23:51:19 2019 , Figure  3648 (total  8064 )
# Mon Apr 15 23:53:24 2019 , Figure  3664 (total  8064 )
# Mon Apr 15 23:55:29 2019 , Figure  3680 (total  8064 )
# Mon Apr 15 23:57:34 2019 , Figure  3696 (total  8064 )
# Mon Apr 15 23:59:39 2019 , Figure  3712 (total  8064 )
# Tue Apr 16 00:01:44 2019 , Figure  3728 (total  8064 )
# Tue Apr 16 00:03:50 2019 , Figure  3744 (total  8064 )
# Tue Apr 16 00:05:55 2019 , Figure  3760 (total  8064 )
# Tue Apr 16 00:08:00 2019 , Figure  3776 (total  8064 )
# Tue Apr 16 00:10:06 2019 , Figure  3792 (total  8064 )
# Tue Apr 16 00:12:10 2019 , Figure  3808 (total  8064 )
# Tue Apr 16 00:14:16 2019 , Figure  3824 (total  8064 )
# Tue Apr 16 00:16:21 2019 , Figure  3840 (total  8064 )
# Tue Apr 16 00:18:26 2019 , Figure  3856 (total  8064 )
# Tue Apr 16 00:20:31 2019 , Figure  3872 (total  8064 )
# Tue Apr 16 00:22:36 2019 , Figure  3888 (total  8064 )
# Tue Apr 16 00:24:41 2019 , Figure  3904 (total  8064 )
# Tue Apr 16 00:26:46 2019 , Figure  3920 (total  8064 )
# Tue Apr 16 00:28:52 2019 , Figure  3936 (total  8064 )
# Tue Apr 16 00:30:57 2019 , Figure  3952 (total  8064 )
# Tue Apr 16 08:02:52 2019 , Figure  7392 (total  8064 )
# Tue Apr 16 08:04:58 2019 , Figure  7408 (total  8064 )
# Tue Apr 16 08:07:03 2019 , Figure  7424 (total  8064 )
# Tue Apr 16 08:09:09 2019 , Figure  7440 (total  8064 )
# Tue Apr 16 08:11:14 2019 , Figure  7456 (total  8064 )
# Tue Apr 16 08:13:20 2019 , Figure  7472 (total  8064 )
# Tue Apr 16 08:15:25 2019 , Figure  7488 (total  8064 )
# Tue Apr 16 08:17:32 2019 , Figure  7504 (total  8064 )
# Tue Apr 16 08:19:38 2019 , Figure  7520 (total  8064 )
# Tue Apr 16 08:21:45 2019 , Figure  7536 (total  8064 )
# Tue Apr 16 08:23:50 2019 , Figure  7552 (total  8064 )
# Tue Apr 16 08:25:56 2019 , Figure  7568 (total  8064 )
# Tue Apr 16 08:28:02 2019 , Figure  7584 (total  8064 )
# Tue Apr 16 08:30:07 2019 , Figure  7600 (total  8064 )
# Tue Apr 16 08:32:13 2019 , Figure  7616 (total  8064 )
# Tue Apr 16 08:34:18 2019 , Figure  7632 (total  8064 )
# Tue Apr 16 08:36:24 2019 , Figure  7648 (total  8064 )
# Tue Apr 16 08:38:29 2019 , Figure  7664 (total  8064 )
# Tue Apr 16 08:40:35 2019 , Figure  7680 (total  8064 )
# Tue Apr 16 08:42:41 2019 , Figure  7696 (total  8064 )
# Tue Apr 16 08:44:45 2019 , Figure  7712 (total  8064 )
# Tue Apr 16 08:46:50 2019 , Figure  7728 (total  8064 )
# Tue Apr 16 08:48:56 2019 , Figure  7744 (total  8064 )
# Tue Apr 16 08:51:01 2019 , Figure  7760 (total  8064 )
# Tue Apr 16 08:53:06 2019 , Figure  7776 (total  8064 )
# Tue Apr 16 08:55:12 2019 , Figure  7792 (total  8064 )
# Tue Apr 16 08:57:17 2019 , Figure  7808 (total  8064 )
# Tue Apr 16 08:59:22 2019 , Figure  7824 (total  8064 )
# Tue Apr 16 09:01:27 2019 , Figure  7840 (total  8064 )
# Tue Apr 16 09:03:32 2019 , Figure  7856 (total  8064 )
# Tue Apr 16 09:05:37 2019 , Figure  7872 (total  8064 )
# Tue Apr 16 09:07:40 2019 , Figure  7888 (total  8064 )
# Tue Apr 16 09:09:43 2019 , Figure  7904 (total  8064 )
# Tue Apr 16 09:11:46 2019 , Figure  7920 (total  8064 )
# Tue Apr 16 09:13:49 2019 , Figure  7936 (total  8064 )
# Tue Apr 16 09:15:53 2019 , Figure  7952 (total  8064 )
# Tue Apr 16 09:17:55 2019 , Figure  7968 (total  8064 )
# Tue Apr 16 09:19:59 2019 , Figure  7984 (total  8064 )
# Tue Apr 16 09:22:01 2019 , Figure  8000 (total  8064 )
# Tue Apr 16 09:24:03 2019 , Figure  8016 (total  8064 )
# Tue Apr 16 09:26:05 2019 , Figure  8032 (total  8064 )
# Tue Apr 16 09:28:07 2019 , Figure  8048 (total  8064 )
# Tue Apr 16 09:30:10 2019 , Figure  8064 (total  8064 )
