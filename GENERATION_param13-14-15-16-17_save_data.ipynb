# %% [markdown]
# # Generation of the simulation
# ### save one example of time series and all measures

# %%
import time as tm
import colorsys
import pickle # package use to save data

exec(open("object.py").read(), globals())
exec(open("variability.py").read(), globals())

exec(open("param.py").read(), globals())
#DOSSIER = "../plot/test/"

# %%
def param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name):
   # Color = ["blue", "g", "red", "orange", "pink", "black", "magenta", "grey"]
    Param_coupled = {"alpha":alpha,
                     "beta":beta}
    Param_freq = {"p":-1} # going to change
    Param_strength = {"scale":strength}
    Fire_param = {"model": "coupled",
                    "frequence": "bernoulli",
                    "param_freq" : Param_freq,
                    "amplitude": "exponential",
                    "Param_strength" : Param_strength,
                    "Param_coupled" : Param_coupled,
                    "type" : "proportionnal",
                    "coef_W_N" : 5}

    # Initialization of arrays
    Collapse = np.zeros((numbreDePoint, len(Freq), Number_of_simulation))
    Variability_always = np.zeros_like(Collapse)
    Variability_until = np.zeros_like(Collapse)
    Variability_only = np.zeros_like(Collapse)
    Variability_10 = np.zeros_like(Collapse)
    Collapse_10_b = np.zeros_like(Collapse)
    Collapse_10_m = np.zeros_like(Collapse)
    Variability_half = np.zeros_like(Collapse)
    Speed_collapse = np.zeros_like(Collapse)
    Viability = np.zeros_like(Collapse)
    Ratio = np.zeros_like(Collapse)
    Point = np.zeros_like(Collapse)
    Time_rotation_N = np.zeros_like(Collapse)
    Time_rotation_W = np.zeros_like(Collapse)
    
    #Exemples = np.zeros(len(Freq))
    
    for i, freq in enumerate(Freq):
        Param_freq = {"p":freq}
        Fire_param["param_freq"] = Param_freq
        exemples(name = name, Number_of_simulation = Number_of_simulation, mean = False, finalTime = finalTime, Fire_param = Fire_param, dt = dt, Param_phy=Param_phy, Init=Init)
        for j in range(numbreDePoint):
            #Variability_half[j,i]
            #Speed_collapse[j,i]
            #Viability[j,i]
            Collapse[j,i], Variability_always[j,i], Variability_until[j,i], Variability_only[j,i], Variability_10[j,i], Collapse_10_b[j,i], Collapse_10_m[j,i], Variability_half[j,i], Speed_collapse[j,i], Viability[j,i], Ratio[j,i], Point[j,i], Time_rotation_N[j,i], Time_rotation_W[j,i] = all_measure(Number_of_simulation = Number_of_simulation, mean = False, finalTime = finalTime, Fire_param = Fire_param, dt = dt, Param_phy=Param_phy, Init=Init)
     
    Measures = {"Collapse": Collapse,
                "Variability_always": Variability_always,
                "Variability_until": Variability_until, 
                "Variability_only":Variability_only,
                "Variability_10":Variability_10,
                "Variability_half":Variability_half,
                "Speed_collapse":Speed_collapse,
                "Viability":Viability,
                "Ratio":Ratio,
                "Point":Point,
                "Time_rotation_N":Time_rotation_N,
                "Time_rotation_W":Time_rotation_W}
    
    # save data
    pickle_out = open(name+".txt","wb")
    pickle.dump(Measures, pickle_out)
    pickle_out.close()
    
    return

# %%
nomberFigure = len(N0)*len(W0)*len(FinalTime)*len(A)*len(M)*len(Alpha)*len(Beta)*len(Strength)

c=0
for n0 in N0:
    for w0 in W0:
        Init = [n0, w0]
        for finalTime in FinalTime:
            for a in A:
                for m in M:
                    Param_phy = [a, m]
                    #Init = [1., Param_phy[1]]
                    for strength in Strength:
                        for alpha in Alpha:
                            for beta in Beta:
                                name = DOSSIER+"n0="+str(n0)+"_w0="+str(w0)+"_final_time="+str(finalTime)+"_a="+str(a)+"_m="+str(m)+"_strength="+str(strength)+"_alpha="+str(alpha)+"_beta="+str(beta)
                                param_study(Number_of_simulation, numbreDePoint, Freq, Param_phy, Init, finalTime, alpha, beta, strength, dt, name)           
                                c+=1
                                print(tm.ctime(), ", Figure ", c*7, "(total ", 7*nomberFigure, ")") # afficher l'heure
# Out:
# Thu Apr 11 16:54:27 2019 , Figure  7 (total  3528 )
# Thu Apr 11 16:56:26 2019 , Figure  14 (total  3528 )
# Thu Apr 11 16:58:26 2019 , Figure  21 (total  3528 )
# Thu Apr 11 17:00:25 2019 , Figure  28 (total  3528 )
# Thu Apr 11 17:02:25 2019 , Figure  35 (total  3528 )
# Thu Apr 11 17:04:26 2019 , Figure  42 (total  3528 )
# Thu Apr 11 17:06:25 2019 , Figure  49 (total  3528 )
# Thu Apr 11 17:08:25 2019 , Figure  56 (total  3528 )
# Thu Apr 11 17:10:24 2019 , Figure  63 (total  3528 )
# Thu Apr 11 17:12:23 2019 , Figure  70 (total  3528 )
# Thu Apr 11 17:14:23 2019 , Figure  77 (total  3528 )
# Thu Apr 11 17:16:23 2019 , Figure  84 (total  3528 )
# Thu Apr 11 17:18:22 2019 , Figure  91 (total  3528 )
# Thu Apr 11 17:20:22 2019 , Figure  98 (total  3528 )
# Thu Apr 11 17:22:21 2019 , Figure  105 (total  3528 )
# Thu Apr 11 17:24:21 2019 , Figure  112 (total  3528 )
# Thu Apr 11 17:26:20 2019 , Figure  119 (total  3528 )
# Thu Apr 11 17:28:20 2019 , Figure  126 (total  3528 )
# Thu Apr 11 17:30:20 2019 , Figure  133 (total  3528 )
# Thu Apr 11 17:32:19 2019 , Figure  140 (total  3528 )
# Thu Apr 11 17:34:19 2019 , Figure  147 (total  3528 )
# Thu Apr 11 17:36:18 2019 , Figure  154 (total  3528 )
# Thu Apr 11 17:38:18 2019 , Figure  161 (total  3528 )
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:273: RuntimeWarning: divide by zero encountered in double_scalars
# Thu Apr 11 17:40:19 2019 , Figure  168 (total  3528 )
# Thu Apr 11 17:42:18 2019 , Figure  175 (total  3528 )
# Thu Apr 11 17:44:20 2019 , Figure  182 (total  3528 )
# Thu Apr 11 17:46:23 2019 , Figure  189 (total  3528 )
# Thu Apr 11 17:48:26 2019 , Figure  196 (total  3528 )
# Thu Apr 11 17:50:26 2019 , Figure  203 (total  3528 )
# Thu Apr 11 17:52:26 2019 , Figure  210 (total  3528 )
# Thu Apr 11 17:54:27 2019 , Figure  217 (total  3528 )
# Thu Apr 11 17:56:28 2019 , Figure  224 (total  3528 )
# Thu Apr 11 17:58:28 2019 , Figure  231 (total  3528 )
# Thu Apr 11 19:26:58 2019 , Figure  539 (total  3528 )
# C:\Users\jerome\Anaconda3\lib\site-packages\ipykernel_launcher.py:166: RuntimeWarning: divide by zero encountered in true_divide
# Thu Apr 11 19:28:58 2019 , Figure  546 (total  3528 )
# Thu Apr 11 19:30:58 2019 , Figure  553 (total  3528 )
# Thu Apr 11 19:32:58 2019 , Figure  560 (total  3528 )
# Thu Apr 11 19:34:58 2019 , Figure  567 (total  3528 )
# Thu Apr 11 19:36:58 2019 , Figure  574 (total  3528 )
# Thu Apr 11 19:38:58 2019 , Figure  581 (total  3528 )
# Thu Apr 11 19:40:58 2019 , Figure  588 (total  3528 )
# Thu Apr 11 19:42:58 2019 , Figure  595 (total  3528 )
# Thu Apr 11 19:44:57 2019 , Figure  602 (total  3528 )
# Thu Apr 11 19:46:57 2019 , Figure  609 (total  3528 )
# Thu Apr 11 19:48:55 2019 , Figure  616 (total  3528 )
# Thu Apr 11 19:50:54 2019 , Figure  623 (total  3528 )
# Thu Apr 11 19:52:53 2019 , Figure  630 (total  3528 )
# Thu Apr 11 19:54:53 2019 , Figure  637 (total  3528 )
# Thu Apr 11 19:56:53 2019 , Figure  644 (total  3528 )
# Thu Apr 11 19:58:53 2019 , Figure  651 (total  3528 )
# Thu Apr 11 20:00:51 2019 , Figure  658 (total  3528 )
# Thu Apr 11 20:02:50 2019 , Figure  665 (total  3528 )
# Thu Apr 11 20:04:48 2019 , Figure  672 (total  3528 )
# Thu Apr 11 20:06:46 2019 , Figure  679 (total  3528 )
# Thu Apr 11 20:08:43 2019 , Figure  686 (total  3528 )
# Thu Apr 11 20:10:41 2019 , Figure  693 (total  3528 )
# Thu Apr 11 20:12:40 2019 , Figure  700 (total  3528 )
# Thu Apr 11 20:14:39 2019 , Figure  707 (total  3528 )
# Thu Apr 11 20:16:38 2019 , Figure  714 (total  3528 )
# Thu Apr 11 20:18:35 2019 , Figure  721 (total  3528 )
# Thu Apr 11 20:20:32 2019 , Figure  728 (total  3528 )
# Thu Apr 11 20:22:29 2019 , Figure  735 (total  3528 )
# Thu Apr 11 20:24:26 2019 , Figure  742 (total  3528 )
# Thu Apr 11 20:26:23 2019 , Figure  749 (total  3528 )
# Thu Apr 11 20:28:20 2019 , Figure  756 (total  3528 )
# Thu Apr 11 20:30:18 2019 , Figure  763 (total  3528 )
# Thu Apr 11 20:32:16 2019 , Figure  770 (total  3528 )
# Thu Apr 11 20:34:14 2019 , Figure  777 (total  3528 )
# Thu Apr 11 20:36:11 2019 , Figure  784 (total  3528 )
# Thu Apr 11 20:38:08 2019 , Figure  791 (total  3528 )
# Thu Apr 11 20:40:04 2019 , Figure  798 (total  3528 )
# Thu Apr 11 20:42:01 2019 , Figure  805 (total  3528 )
# Thu Apr 11 20:43:58 2019 , Figure  812 (total  3528 )
# Thu Apr 11 20:45:54 2019 , Figure  819 (total  3528 )
# Thu Apr 11 20:47:52 2019 , Figure  826 (total  3528 )
# Thu Apr 11 23:42:17 2019 , Figure  1435 (total  3528 )
# Thu Apr 11 23:44:17 2019 , Figure  1442 (total  3528 )
# Thu Apr 11 23:46:17 2019 , Figure  1449 (total  3528 )
# Thu Apr 11 23:48:18 2019 , Figure  1456 (total  3528 )
# Thu Apr 11 23:50:19 2019 , Figure  1463 (total  3528 )
# Thu Apr 11 23:52:20 2019 , Figure  1470 (total  3528 )
# Thu Apr 11 23:54:20 2019 , Figure  1477 (total  3528 )
# Thu Apr 11 23:56:20 2019 , Figure  1484 (total  3528 )
# Thu Apr 11 23:58:20 2019 , Figure  1491 (total  3528 )
# Fri Apr 12 00:00:19 2019 , Figure  1498 (total  3528 )
# Fri Apr 12 00:02:18 2019 , Figure  1505 (total  3528 )
# Fri Apr 12 00:04:17 2019 , Figure  1512 (total  3528 )
# Fri Apr 12 00:06:17 2019 , Figure  1519 (total  3528 )
# Fri Apr 12 00:08:18 2019 , Figure  1526 (total  3528 )
# Fri Apr 12 00:10:18 2019 , Figure  1533 (total  3528 )
# Fri Apr 12 00:12:17 2019 , Figure  1540 (total  3528 )
# Fri Apr 12 00:14:15 2019 , Figure  1547 (total  3528 )
# Fri Apr 12 00:16:14 2019 , Figure  1554 (total  3528 )
# Fri Apr 12 00:18:11 2019 , Figure  1561 (total  3528 )
# Fri Apr 12 00:20:10 2019 , Figure  1568 (total  3528 )
# Fri Apr 12 00:22:08 2019 , Figure  1575 (total  3528 )
# Fri Apr 12 00:24:06 2019 , Figure  1582 (total  3528 )
# Fri Apr 12 00:26:05 2019 , Figure  1589 (total  3528 )
# Fri Apr 12 00:28:05 2019 , Figure  1596 (total  3528 )
# Fri Apr 12 00:30:02 2019 , Figure  1603 (total  3528 )
# Fri Apr 12 00:31:59 2019 , Figure  1610 (total  3528 )
# Fri Apr 12 00:33:57 2019 , Figure  1617 (total  3528 )
# Fri Apr 12 00:35:55 2019 , Figure  1624 (total  3528 )
# Fri Apr 12 00:37:52 2019 , Figure  1631 (total  3528 )
# Fri Apr 12 00:39:50 2019 , Figure  1638 (total  3528 )
# Fri Apr 12 00:41:48 2019 , Figure  1645 (total  3528 )
# Fri Apr 12 00:43:46 2019 , Figure  1652 (total  3528 )
# Fri Apr 12 00:45:44 2019 , Figure  1659 (total  3528 )
# Fri Apr 12 00:47:42 2019 , Figure  1666 (total  3528 )
# Fri Apr 12 00:49:39 2019 , Figure  1673 (total  3528 )
# Fri Apr 12 00:51:36 2019 , Figure  1680 (total  3528 )
# Fri Apr 12 00:53:34 2019 , Figure  1687 (total  3528 )
# Fri Apr 12 00:55:31 2019 , Figure  1694 (total  3528 )
# Fri Apr 12 00:57:28 2019 , Figure  1701 (total  3528 )
# Fri Apr 12 00:59:26 2019 , Figure  1708 (total  3528 )
# Fri Apr 12 01:01:24 2019 , Figure  1715 (total  3528 )
# Fri Apr 12 01:03:22 2019 , Figure  1722 (total  3528 )
# Fri Apr 12 01:05:19 2019 , Figure  1729 (total  3528 )
# Fri Apr 12 01:07:17 2019 , Figure  1736 (total  3528 )
# Fri Apr 12 01:09:14 2019 , Figure  1743 (total  3528 )
# Fri Apr 12 01:11:11 2019 , Figure  1750 (total  3528 )
# Fri Apr 12 01:13:08 2019 , Figure  1757 (total  3528 )
# Fri Apr 12 01:15:05 2019 , Figure  1764 (total  3528 )
# Fri Apr 12 01:17:06 2019 , Figure  1771 (total  3528 )
# Fri Apr 12 01:19:07 2019 , Figure  1778 (total  3528 )
# Fri Apr 12 01:21:08 2019 , Figure  1785 (total  3528 )
# Fri Apr 12 01:23:08 2019 , Figure  1792 (total  3528 )
# Fri Apr 12 01:25:09 2019 , Figure  1799 (total  3528 )
# Fri Apr 12 01:27:09 2019 , Figure  1806 (total  3528 )
# Fri Apr 12 01:29:10 2019 , Figure  1813 (total  3528 )
# Fri Apr 12 01:31:11 2019 , Figure  1820 (total  3528 )
# Fri Apr 12 01:33:11 2019 , Figure  1827 (total  3528 )
# Fri Apr 12 01:35:12 2019 , Figure  1834 (total  3528 )
# Fri Apr 12 01:37:12 2019 , Figure  1841 (total  3528 )
# Fri Apr 12 01:39:13 2019 , Figure  1848 (total  3528 )
# Fri Apr 12 01:41:13 2019 , Figure  1855 (total  3528 )
# Fri Apr 12 01:43:14 2019 , Figure  1862 (total  3528 )
# Fri Apr 12 01:45:14 2019 , Figure  1869 (total  3528 )
# Fri Apr 12 01:47:15 2019 , Figure  1876 (total  3528 )
# Fri Apr 12 01:49:15 2019 , Figure  1883 (total  3528 )
# Fri Apr 12 01:51:16 2019 , Figure  1890 (total  3528 )
# Fri Apr 12 01:53:16 2019 , Figure  1897 (total  3528 )
# Fri Apr 12 01:55:17 2019 , Figure  1904 (total  3528 )
# Fri Apr 12 01:57:17 2019 , Figure  1911 (total  3528 )
# Fri Apr 12 01:59:18 2019 , Figure  1918 (total  3528 )
# Fri Apr 12 02:01:19 2019 , Figure  1925 (total  3528 )
# Fri Apr 12 02:03:20 2019 , Figure  1932 (total  3528 )
# Fri Apr 12 02:05:20 2019 , Figure  1939 (total  3528 )
# Fri Apr 12 02:07:21 2019 , Figure  1946 (total  3528 )
# Fri Apr 12 02:09:22 2019 , Figure  1953 (total  3528 )
# Fri Apr 12 02:11:23 2019 , Figure  1960 (total  3528 )
# Fri Apr 12 02:13:24 2019 , Figure  1967 (total  3528 )
# Fri Apr 12 02:15:25 2019 , Figure  1974 (total  3528 )
# Fri Apr 12 02:17:25 2019 , Figure  1981 (total  3528 )
# Fri Apr 12 02:19:26 2019 , Figure  1988 (total  3528 )
# Fri Apr 12 02:21:27 2019 , Figure  1995 (total  3528 )
# Fri Apr 12 02:23:28 2019 , Figure  2002 (total  3528 )
# Fri Apr 12 02:25:29 2019 , Figure  2009 (total  3528 )
# Fri Apr 12 02:27:30 2019 , Figure  2016 (total  3528 )
# Fri Apr 12 02:29:30 2019 , Figure  2023 (total  3528 )
# Fri Apr 12 02:31:31 2019 , Figure  2030 (total  3528 )
# Fri Apr 12 02:33:32 2019 , Figure  2037 (total  3528 )
# Fri Apr 12 02:35:33 2019 , Figure  2044 (total  3528 )
# Fri Apr 12 02:37:34 2019 , Figure  2051 (total  3528 )
# Fri Apr 12 02:39:35 2019 , Figure  2058 (total  3528 )
# Fri Apr 12 02:41:35 2019 , Figure  2065 (total  3528 )
# Fri Apr 12 02:43:37 2019 , Figure  2072 (total  3528 )
# Fri Apr 12 02:45:38 2019 , Figure  2079 (total  3528 )
# Fri Apr 12 02:47:39 2019 , Figure  2086 (total  3528 )
# Fri Apr 12 02:49:39 2019 , Figure  2093 (total  3528 )
# Fri Apr 12 02:51:40 2019 , Figure  2100 (total  3528 )
# Fri Apr 12 02:53:41 2019 , Figure  2107 (total  3528 )
# Fri Apr 12 02:55:43 2019 , Figure  2114 (total  3528 )
# Fri Apr 12 02:57:44 2019 , Figure  2121 (total  3528 )
# Fri Apr 12 02:59:45 2019 , Figure  2128 (total  3528 )
# Fri Apr 12 03:01:46 2019 , Figure  2135 (total  3528 )
# Fri Apr 12 03:03:47 2019 , Figure  2142 (total  3528 )
# Fri Apr 12 03:05:48 2019 , Figure  2149 (total  3528 )
# Fri Apr 12 03:07:49 2019 , Figure  2156 (total  3528 )
# Fri Apr 12 03:09:50 2019 , Figure  2163 (total  3528 )
# Fri Apr 12 03:11:51 2019 , Figure  2170 (total  3528 )
# Fri Apr 12 03:13:52 2019 , Figure  2177 (total  3528 )
# Fri Apr 12 03:15:53 2019 , Figure  2184 (total  3528 )
# Fri Apr 12 03:17:54 2019 , Figure  2191 (total  3528 )
# Fri Apr 12 03:19:55 2019 , Figure  2198 (total  3528 )
# Fri Apr 12 03:21:57 2019 , Figure  2205 (total  3528 )
# Fri Apr 12 03:23:57 2019 , Figure  2212 (total  3528 )
# Fri Apr 12 03:25:59 2019 , Figure  2219 (total  3528 )
# Fri Apr 12 03:28:00 2019 , Figure  2226 (total  3528 )
# Fri Apr 12 03:30:01 2019 , Figure  2233 (total  3528 )
# Fri Apr 12 03:32:02 2019 , Figure  2240 (total  3528 )
# Fri Apr 12 03:34:03 2019 , Figure  2247 (total  3528 )
# Fri Apr 12 03:36:04 2019 , Figure  2254 (total  3528 )
# Fri Apr 12 03:38:05 2019 , Figure  2261 (total  3528 )
# Fri Apr 12 03:40:06 2019 , Figure  2268 (total  3528 )
# Fri Apr 12 03:42:06 2019 , Figure  2275 (total  3528 )
# Fri Apr 12 03:44:08 2019 , Figure  2282 (total  3528 )
# Fri Apr 12 03:46:09 2019 , Figure  2289 (total  3528 )
# Fri Apr 12 03:48:10 2019 , Figure  2296 (total  3528 )
# Fri Apr 12 03:50:10 2019 , Figure  2303 (total  3528 )
# Fri Apr 12 03:52:11 2019 , Figure  2310 (total  3528 )
# Fri Apr 12 03:54:10 2019 , Figure  2317 (total  3528 )
# Fri Apr 12 03:56:11 2019 , Figure  2324 (total  3528 )
# Fri Apr 12 03:58:11 2019 , Figure  2331 (total  3528 )
# Fri Apr 12 04:00:11 2019 , Figure  2338 (total  3528 )
# Fri Apr 12 04:02:12 2019 , Figure  2345 (total  3528 )
# Fri Apr 12 04:04:13 2019 , Figure  2352 (total  3528 )
# Fri Apr 12 04:06:13 2019 , Figure  2359 (total  3528 )
# Fri Apr 12 04:08:13 2019 , Figure  2366 (total  3528 )
# Fri Apr 12 04:10:13 2019 , Figure  2373 (total  3528 )
# Fri Apr 12 04:12:12 2019 , Figure  2380 (total  3528 )
# Fri Apr 12 04:14:11 2019 , Figure  2387 (total  3528 )
# Fri Apr 12 04:16:10 2019 , Figure  2394 (total  3528 )
# Fri Apr 12 04:18:10 2019 , Figure  2401 (total  3528 )
# Fri Apr 12 04:20:10 2019 , Figure  2408 (total  3528 )
# Fri Apr 12 04:22:11 2019 , Figure  2415 (total  3528 )
# Fri Apr 12 04:24:09 2019 , Figure  2422 (total  3528 )
# Fri Apr 12 04:26:08 2019 , Figure  2429 (total  3528 )
# Fri Apr 12 04:28:06 2019 , Figure  2436 (total  3528 )
# Fri Apr 12 04:30:04 2019 , Figure  2443 (total  3528 )
# Fri Apr 12 04:32:02 2019 , Figure  2450 (total  3528 )
# Fri Apr 12 04:34:00 2019 , Figure  2457 (total  3528 )
# Fri Apr 12 04:35:59 2019 , Figure  2464 (total  3528 )
# Fri Apr 12 04:37:58 2019 , Figure  2471 (total  3528 )
# Fri Apr 12 04:39:57 2019 , Figure  2478 (total  3528 )
# Fri Apr 12 04:41:54 2019 , Figure  2485 (total  3528 )
# Fri Apr 12 04:43:52 2019 , Figure  2492 (total  3528 )
# Fri Apr 12 04:45:50 2019 , Figure  2499 (total  3528 )
# Fri Apr 12 04:47:47 2019 , Figure  2506 (total  3528 )
# Fri Apr 12 04:49:45 2019 , Figure  2513 (total  3528 )
# Fri Apr 12 04:51:42 2019 , Figure  2520 (total  3528 )
# Fri Apr 12 04:53:40 2019 , Figure  2527 (total  3528 )
# Fri Apr 12 04:55:38 2019 , Figure  2534 (total  3528 )
# Fri Apr 12 04:57:37 2019 , Figure  2541 (total  3528 )
# Fri Apr 12 04:59:34 2019 , Figure  2548 (total  3528 )
# Fri Apr 12 05:01:32 2019 , Figure  2555 (total  3528 )
# Fri Apr 12 05:03:30 2019 , Figure  2562 (total  3528 )
# Fri Apr 12 05:05:27 2019 , Figure  2569 (total  3528 )
# Fri Apr 12 05:07:24 2019 , Figure  2576 (total  3528 )
# Fri Apr 12 05:09:22 2019 , Figure  2583 (total  3528 )
# Fri Apr 12 05:11:20 2019 , Figure  2590 (total  3528 )
# Fri Apr 12 05:13:18 2019 , Figure  2597 (total  3528 )
# Fri Apr 12 05:15:16 2019 , Figure  2604 (total  3528 )
# Fri Apr 12 05:17:13 2019 , Figure  2611 (total  3528 )
# Fri Apr 12 05:19:10 2019 , Figure  2618 (total  3528 )
# Fri Apr 12 05:21:07 2019 , Figure  2625 (total  3528 )
# Fri Apr 12 05:23:05 2019 , Figure  2632 (total  3528 )
# Fri Apr 12 05:25:02 2019 , Figure  2639 (total  3528 )
# Fri Apr 12 05:26:59 2019 , Figure  2646 (total  3528 )
# Fri Apr 12 05:29:00 2019 , Figure  2653 (total  3528 )
# Fri Apr 12 05:31:00 2019 , Figure  2660 (total  3528 )
# Fri Apr 12 05:33:01 2019 , Figure  2667 (total  3528 )
# Fri Apr 12 05:35:01 2019 , Figure  2674 (total  3528 )
# Fri Apr 12 05:37:02 2019 , Figure  2681 (total  3528 )
# Fri Apr 12 05:39:02 2019 , Figure  2688 (total  3528 )
# Fri Apr 12 05:41:03 2019 , Figure  2695 (total  3528 )
# Fri Apr 12 05:43:04 2019 , Figure  2702 (total  3528 )
# Fri Apr 12 05:45:04 2019 , Figure  2709 (total  3528 )
# Fri Apr 12 05:47:05 2019 , Figure  2716 (total  3528 )
# Fri Apr 12 05:49:06 2019 , Figure  2723 (total  3528 )
# Fri Apr 12 05:51:07 2019 , Figure  2730 (total  3528 )
# Fri Apr 12 05:53:08 2019 , Figure  2737 (total  3528 )
# Fri Apr 12 05:55:09 2019 , Figure  2744 (total  3528 )
# Fri Apr 12 05:57:09 2019 , Figure  2751 (total  3528 )
# Fri Apr 12 05:59:10 2019 , Figure  2758 (total  3528 )
# Fri Apr 12 06:01:11 2019 , Figure  2765 (total  3528 )
# Fri Apr 12 06:03:12 2019 , Figure  2772 (total  3528 )
# Fri Apr 12 06:05:13 2019 , Figure  2779 (total  3528 )
# Fri Apr 12 06:07:13 2019 , Figure  2786 (total  3528 )
# Fri Apr 12 06:09:14 2019 , Figure  2793 (total  3528 )
# Fri Apr 12 06:11:14 2019 , Figure  2800 (total  3528 )
# Fri Apr 12 06:13:15 2019 , Figure  2807 (total  3528 )
# Fri Apr 12 06:15:16 2019 , Figure  2814 (total  3528 )
# Fri Apr 12 06:17:17 2019 , Figure  2821 (total  3528 )
# Fri Apr 12 06:19:18 2019 , Figure  2828 (total  3528 )
# Fri Apr 12 06:21:19 2019 , Figure  2835 (total  3528 )
# Fri Apr 12 06:23:20 2019 , Figure  2842 (total  3528 )
# Fri Apr 12 06:25:21 2019 , Figure  2849 (total  3528 )
# Fri Apr 12 06:27:22 2019 , Figure  2856 (total  3528 )
# Fri Apr 12 06:29:23 2019 , Figure  2863 (total  3528 )
# Fri Apr 12 06:31:24 2019 , Figure  2870 (total  3528 )
# Fri Apr 12 06:33:25 2019 , Figure  2877 (total  3528 )
# Fri Apr 12 06:35:26 2019 , Figure  2884 (total  3528 )
# Fri Apr 12 06:37:27 2019 , Figure  2891 (total  3528 )
# Fri Apr 12 06:39:29 2019 , Figure  2898 (total  3528 )
# Fri Apr 12 06:41:30 2019 , Figure  2905 (total  3528 )
# Fri Apr 12 06:43:30 2019 , Figure  2912 (total  3528 )
# Fri Apr 12 06:45:32 2019 , Figure  2919 (total  3528 )
# Fri Apr 12 06:47:33 2019 , Figure  2926 (total  3528 )
# Fri Apr 12 06:49:34 2019 , Figure  2933 (total  3528 )
# Fri Apr 12 06:51:35 2019 , Figure  2940 (total  3528 )
# Fri Apr 12 06:53:37 2019 , Figure  2947 (total  3528 )
# Fri Apr 12 06:55:38 2019 , Figure  2954 (total  3528 )
# Fri Apr 12 06:57:39 2019 , Figure  2961 (total  3528 )
# Fri Apr 12 06:59:40 2019 , Figure  2968 (total  3528 )
# Fri Apr 12 07:01:42 2019 , Figure  2975 (total  3528 )
# Fri Apr 12 07:03:43 2019 , Figure  2982 (total  3528 )
# Fri Apr 12 07:05:44 2019 , Figure  2989 (total  3528 )
# Fri Apr 12 07:07:45 2019 , Figure  2996 (total  3528 )
# Fri Apr 12 07:09:46 2019 , Figure  3003 (total  3528 )
# Fri Apr 12 07:11:47 2019 , Figure  3010 (total  3528 )
# Fri Apr 12 07:13:48 2019 , Figure  3017 (total  3528 )
# Fri Apr 12 07:15:49 2019 , Figure  3024 (total  3528 )
# Fri Apr 12 07:17:51 2019 , Figure  3031 (total  3528 )
# Fri Apr 12 07:19:52 2019 , Figure  3038 (total  3528 )
# Fri Apr 12 07:21:53 2019 , Figure  3045 (total  3528 )
# Fri Apr 12 07:23:55 2019 , Figure  3052 (total  3528 )
# Fri Apr 12 07:25:56 2019 , Figure  3059 (total  3528 )
# Fri Apr 12 07:27:57 2019 , Figure  3066 (total  3528 )
# Fri Apr 12 07:29:59 2019 , Figure  3073 (total  3528 )
# Fri Apr 12 07:32:00 2019 , Figure  3080 (total  3528 )
# Fri Apr 12 07:34:01 2019 , Figure  3087 (total  3528 )
# Fri Apr 12 07:36:02 2019 , Figure  3094 (total  3528 )
# Fri Apr 12 07:38:03 2019 , Figure  3101 (total  3528 )
# Fri Apr 12 07:40:05 2019 , Figure  3108 (total  3528 )
# Fri Apr 12 07:42:05 2019 , Figure  3115 (total  3528 )
# Fri Apr 12 07:44:06 2019 , Figure  3122 (total  3528 )
# Fri Apr 12 07:46:07 2019 , Figure  3129 (total  3528 )
# Fri Apr 12 07:48:07 2019 , Figure  3136 (total  3528 )
# Fri Apr 12 07:50:08 2019 , Figure  3143 (total  3528 )
# Fri Apr 12 07:52:09 2019 , Figure  3150 (total  3528 )
# Fri Apr 12 07:54:09 2019 , Figure  3157 (total  3528 )
# Fri Apr 12 07:56:10 2019 , Figure  3164 (total  3528 )
# Fri Apr 12 07:58:12 2019 , Figure  3171 (total  3528 )
# Fri Apr 12 08:00:12 2019 , Figure  3178 (total  3528 )
# Fri Apr 12 08:02:12 2019 , Figure  3185 (total  3528 )
# Fri Apr 12 08:04:13 2019 , Figure  3192 (total  3528 )
# Fri Apr 12 08:06:13 2019 , Figure  3199 (total  3528 )
# Fri Apr 12 08:08:13 2019 , Figure  3206 (total  3528 )
# Fri Apr 12 08:10:13 2019 , Figure  3213 (total  3528 )
# Fri Apr 12 08:12:14 2019 , Figure  3220 (total  3528 )
# Fri Apr 12 08:14:15 2019 , Figure  3227 (total  3528 )
# Fri Apr 12 08:16:16 2019 , Figure  3234 (total  3528 )
# Fri Apr 12 08:18:15 2019 , Figure  3241 (total  3528 )
# Fri Apr 12 08:20:14 2019 , Figure  3248 (total  3528 )
# Fri Apr 12 08:22:14 2019 , Figure  3255 (total  3528 )
# Fri Apr 12 08:24:13 2019 , Figure  3262 (total  3528 )
# Fri Apr 12 08:26:11 2019 , Figure  3269 (total  3528 )
# Fri Apr 12 08:28:10 2019 , Figure  3276 (total  3528 )
# Fri Apr 12 08:30:10 2019 , Figure  3283 (total  3528 )
# Fri Apr 12 08:32:10 2019 , Figure  3290 (total  3528 )
# Fri Apr 12 08:34:10 2019 , Figure  3297 (total  3528 )
# Fri Apr 12 08:36:08 2019 , Figure  3304 (total  3528 )
# Fri Apr 12 08:38:07 2019 , Figure  3311 (total  3528 )
# Fri Apr 12 08:40:05 2019 , Figure  3318 (total  3528 )
# Fri Apr 12 08:42:04 2019 , Figure  3325 (total  3528 )
# Fri Apr 12 08:44:01 2019 , Figure  3332 (total  3528 )
# Fri Apr 12 08:46:00 2019 , Figure  3339 (total  3528 )
# Fri Apr 12 08:47:58 2019 , Figure  3346 (total  3528 )
# Fri Apr 12 08:49:57 2019 , Figure  3353 (total  3528 )
# Fri Apr 12 08:51:56 2019 , Figure  3360 (total  3528 )
# Fri Apr 12 08:53:54 2019 , Figure  3367 (total  3528 )
# Fri Apr 12 08:55:52 2019 , Figure  3374 (total  3528 )
# Fri Apr 12 08:57:49 2019 , Figure  3381 (total  3528 )
# Fri Apr 12 08:59:47 2019 , Figure  3388 (total  3528 )
# Fri Apr 12 09:01:44 2019 , Figure  3395 (total  3528 )
# Fri Apr 12 09:03:42 2019 , Figure  3402 (total  3528 )
# Fri Apr 12 09:05:40 2019 , Figure  3409 (total  3528 )
# Fri Apr 12 09:07:38 2019 , Figure  3416 (total  3528 )
# Fri Apr 12 09:09:37 2019 , Figure  3423 (total  3528 )
# Fri Apr 12 09:11:34 2019 , Figure  3430 (total  3528 )
# Fri Apr 12 09:13:32 2019 , Figure  3437 (total  3528 )
# Fri Apr 12 09:15:30 2019 , Figure  3444 (total  3528 )
# Fri Apr 12 09:17:27 2019 , Figure  3451 (total  3528 )
# Fri Apr 12 09:19:24 2019 , Figure  3458 (total  3528 )
# Fri Apr 12 09:21:22 2019 , Figure  3465 (total  3528 )
# Fri Apr 12 09:23:20 2019 , Figure  3472 (total  3528 )
# Fri Apr 12 09:25:18 2019 , Figure  3479 (total  3528 )
# Fri Apr 12 09:27:16 2019 , Figure  3486 (total  3528 )
# Fri Apr 12 09:29:13 2019 , Figure  3493 (total  3528 )
# Fri Apr 12 09:31:11 2019 , Figure  3500 (total  3528 )
# Fri Apr 12 09:33:09 2019 , Figure  3507 (total  3528 )
# Fri Apr 12 09:35:06 2019 , Figure  3514 (total  3528 )
# Fri Apr 12 09:37:03 2019 , Figure  3521 (total  3528 )
# Fri Apr 12 09:39:01 2019 , Figure  3528 (total  3528 )
